# %% [markdown]
# <a href="https://colab.research.google.com/github/natalasso15/GNM/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Criptomoneda
p=0
c=0
s=input(("Ingresar el simbolo"))
n=input(("Ingrese la moneda"))
P=int(input("Ingrese el precio actual"))
c=int(input("Ingrese el cambio"))
criptomonedas=P+c
if criptomonedas>1:
  print("La criptomoneda es:",criptomonedas)
  print("E simbolo es:",s)
  print("La moneda es:",n)
  print("El precio actual es:", P)
  print("El cambio es:",c)
# Out:
# Ingresar el simboloL
# Ingrese la monedaLitecoin
# Ingrese el precio actual28461510
# Ingrese el cambio22
# La criptomoneda es: 28461532
# E simbolo es: L
# La moneda es: Litecoin
# El precio actual es: 28461510
# El cambio es: 22
